# %%
import numpy as np

# %%
a=np.array([1,2,3],dtype='int32')

# %%
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# Get Dimension
a.ndim
# Out:
# 1

# %%
b.shape
# Out:
# (2, 3)

# %%
# Get type
a.dtype
# Out:
# dtype('int32')

# %%
a.itemsize
# in bytes
# Out:
# 2

# %%
# Get the total size
a.nbytes
# Out:
# 6
